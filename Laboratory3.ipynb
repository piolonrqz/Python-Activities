# %% [markdown]
# **Problem Statement 1:**
#
# Write a Python function that checks whether a given positive integer is an Armstrong number of order n. An Armstrong number of order n is a number such that the sum of its digits, each raised to the power of n, is equal to the number itself.
#
# **Example:**
# For `num = 153`, the order `n = 3` because 153 has three digits. Now, check if:
# `1^3 + 5^3 + 3^3 = 153`

# %%
#your code here

def armstrong_number():
    num = int(input("Enter a number: "))
    
    sum = 0
    temp = num
    
    while temp > 0:
        digit = temp % 10
        sum += digit ** 3
        temp //= 10

    if num == sum:
        print(num, "is an Armstrong number")
    else:
        print(num, "is not an Armstrong number")

armstrong_number()
# Out:
# 187 is not an Armstrong number

# %% [markdown]
# **Problem Statement 2:**
#
# Write two Python functions: one to convert a binary number to its decimal equivalent and another to convert a decimal number to its binary representation.
#
# 1. **Function 1**: The first function should take a string representing a binary number (composed of '0's and '1's) as input and return the corresponding decimal number as an integer. The function should validate that the input is a valid binary number and then proceed to perform the conversion.
#
# 2. **Function 2**: The second function should take a positive decimal integer as input and return its binary representation as a string. The function should ensure the input is a non-negative integer before performing the conversion.
#
# For both conversions, ensure the code handles edge cases, such as invalid inputs, negative numbers, or very large values, and provide appropriate feedback or error messages.
#
# ### Example:
#
# 1. Input: Binary: "1010"
#    Output: Decimal: 10
#
# 2. Input: Decimal: 18
#    Output: Binary: "10010"
#
# **Use loops only**.

# %%
## Write you function code here

def binary_to_decimal():

    binary_num = input("Binary: ")

    for char in binary_num:
        if char not in ('0', '1'):
            return "Invalid binary input. Please enter a valid binary number."

    decimal_value = 0
    power = 0
    for digit in reversed(binary_num):
        decimal_value += int(digit) * (2 ** power)
        power += 1

    return f"Decimal: {decimal_value}"

# Call the function
print(binary_to_decimal())



def decimal_to_binary():
    try:
        decimal_num = int(input("Decimal: "))
    except ValueError:
        return "Invalid input. Please enter a positive integer."
    
    if decimal_num < 0:
        return "Invalid input. Please enter a positive integer."

    if decimal_num == 0:
        return "Binary: 0"


    binary_num = ""
    while decimal_num > 0:
        remainder = decimal_num % 2
        binary_str = str(remainder) + binary_str
        decimal_num = decimal_num // 2

    return f"Binary: {binary_str}"

print(decimal_to_binary())
# Out:
# The decimal equivalent is: 178
# The binary equivalent is: 11011

# %% [markdown]
# **Problem Statement 3:**
#
# Write two Python functions: one to convert an octal number to its decimal equivalent and another to convert a decimal number to its octal representation.
#
# 1. **Function 1**: The first function should take a string representing an octal number (composed of digits from 0 to 7) as input and return the corresponding decimal number as an integer. The function should validate that the input is a valid octal number before performing the conversion.
#
# 2. **Function 2**: The second function should take a positive decimal integer as input and return its octal representation as a string. The function should ensure the input is a non-negative integer before converting it to octal.
#
# Both functions should handle edge cases such as invalid inputs, negative numbers, or extremely large values, providing appropriate feedback or error messages where necessary. These functions will help students understand how to perform conversions between octal and decimal number systems.
#
# ### Example:
#
# 1. Input: Octal: "157"
#    Output: Decimal: 111
#
# 2. Input: Decimal: 65
#    Output: Octal: "101"

# %%
## Write your functions here

def octal_to_decimal():
    octal_num = input("Octal: ")
    
    for char in octal_num:
        if char not in '01234567':
            return "Invalid octal input. Please enter a valid octal number."

    decimal_value = 0
    power = 0
    for digit in reversed(octal_num):
        decimal_value += int(digit) * (8 ** power)
        power += 1

    return f"Decimal: {decimal_value}"

print(octal_to_decimal())


def decimal_to_octal():
    try:
        decimal_num = int(input("Enter a non-negative decimal number: "))
    except ValueError:
        return "Invalid input. Please enter a non-negative integer."
    
    if decimal_num < 0:
        return "Invalid input. Please enter a non-negative integer."

    if decimal_num == 0:
        return "Octal: 0"

    octal_str = ""
    while decimal_num > 0:
        remainder = decimal_num % 8
        octal_str = str(remainder) + octal_str
        decimal_num = decimal_num // 8

    return f"Octal: {octal_str}"

print(decimal_to_octal())
# Out:
# Decimal: 23
# Octal: 116

# %% [markdown]
# **Problem Statement 4:**
#
# Write two Python functions: one to convert a binary number to its octal equivalent and another to convert an octal number to its binary representation.
#
# 1. **Function 1**: The first function should take a string representing a binary number (composed of '0's and '1's) as input and return the corresponding octal number as a string. The function should first ensure the input is a valid binary number, then convert it to octal.
#
# 2. **Function 2**: The second function should take a string representing an octal number (composed of digits from 0 to 7) as input and return the corresponding binary number as a string. The function should validate that the input is a valid octal number before converting it to binary.
#
# Both functions should handle potential edge cases, such as invalid inputs or very large numbers, and provide appropriate feedback or error messages where necessary. These conversions will help students understand how to efficiently switch between binary and octal number systems without needing an intermediate decimal conversion.
#
# ### Example:
#
# 1. Input: Binary: "110101"
#    Output: Octal: "65"
#
# 2. Input: Octal: "12"
#    Output: Binary: "1010"

# %%
## Write your functions here

def binary_to_octal():
    binary_num = input("Enter a binary number: ")
    for char in binary_num:
        if char not in ('0', '1'):
            return "Invalid binary input. Please enter a valid binary number."

    while len(binary_num) % 3 != 0:
        binary_num = '0' + binary_num

    octal_num = ""
    for i in range(0, len(binary_num), 3):
        binary_group = binary_num[i:i+3]
        octal_digit = str(int(binary_group, 2))
        octal_num += octal_digit

    return f"The octal equivalent is: {octal_num}"


def octal_to_binary():
    octal_num = input("Enter an octal number: ")
    for char in octal_num:
        if char not in '01234567':
            return "Invalid octal input. Please enter a valid octal number."
        
    binary_str = ""
    for digit in octal_num:
        binary_group = format(int(digit), '03b')
        binary_str += binary_group

    binary_num = binary_num.lstrip('0') or '0'

    return f"The binary equivalent is: {binary_num}"

# Call the function
print(octal_to_binary())
# Out:
# Octal: 263
# Binary: 10110011

# %% [markdown]
# **Main**
# Write all your Input statements on all of the problem statements below.

# %%
## Write all your User inputs and and Function usage here

#armstrong number

def armstrong_number(num):
    num_str = str(num)
    num_digits = len(num_str)
    
    sum = 0
    temp = num
    
    while temp > 0:
        digit = temp % 10
        sum += digit ** num_digits
        temp //= 10

    if num == sum:
        print(num, "is an Armstrong number")
    else:
        print(num, "is not an Armstrong number")

for number in [153, 370, 371, 9474, 9475]:
    armstrong_number(number)


#binary to decimal
def binary_to_decimal(binary_num):
    # Validate binary input
    for char in binary_num:
        if char not in ('0', '1'):
            return "Invalid binary input. Please enter a valid binary number."

    decimal_value = 0
    power = 0
    for digit in reversed(binary_num):
        decimal_value += int(digit) * (2 ** power)
        power += 1

    return f"Decimal: {decimal_value}"

binary_tests = ["1101",  "101010",  "0000", "11111111", "1234" ]

for binary_test in binary_tests:
    print(f"Binary to Decimal Test: {binary_test} -> {binary_to_decimal(binary_test)}")



#decimal to binary
def decimal_to_binary(decimal_num):
    try:
        decimal_num = int(decimal_num)
    except ValueError:
        return "Invalid input. Please enter a positive integer."
    
    if decimal_num < 0:
        return "Invalid input. Please enter a positive integer."

    if decimal_num == 0:
        return "Binary: 0"

    binary_num = ""
    while decimal_num > 0:
        remainder = decimal_num % 2
        binary_num = str(remainder) + binary_num
        decimal_num = decimal_num // 2

    return f"Binary: {binary_num}"


decimal_tests = [13, 42, 0, 255, -10]
for decimal_test in decimal_tests:
    print(f"Decimal to Binary Test: {decimal_test} -> {decimal_to_binary(decimal_test)}")





#octal to decimal

def octal_to_decimal(octal_num):
    # Validate octal input
    for char in octal_num:
        if char not in '01234567':
            return "Invalid octal input. Please enter a valid octal number."

    decimal_value = 0
    power = 0
    for digit in reversed(octal_num):
        decimal_value += int(digit) * (8 ** power)
        power += 1

    return f"Decimal: {decimal_value}"


octal_tests = ["10", "127","0", "777", "89"]


for octal_test in octal_tests:
    print(f"Octal to Decimal Test: {octal_test} -> {octal_to_decimal(octal_test)}")




#decimal to octal

def decimal_to_octal(decimal_num):
    try:
        decimal_num = int(decimal_num)
    except ValueError:
        return "Invalid input. Please enter a non-negative integer."
    
    if decimal_num < 0:
        return "Invalid input. Please enter a non-negative integer."

    if decimal_num == 0:
        return "Octal: 0"

    octal_str = ""
    while decimal_num > 0:
        remainder = decimal_num % 8
        octal_str = str(remainder) + octal_str
        decimal_num = decimal_num // 8

    return f"Octal: {octal_str}"


decimal_tests = [13, 42, 0, 255, -10]

for decimal_test in decimal_tests:
    print(f"Decimal to Octal Test: {decimal_test} -> {decimal_to_octal(decimal_test)}")




#binary to octal

def binary_to_octal(binary_num):
    # Validate binary input
    for char in binary_num:
        if char not in ('0', '1'):
            return "Invalid binary input. Please enter a valid binary number."

    # Pad binary number to make its length a multiple of 3
    while len(binary_num) % 3 != 0:
        binary_num = '0' + binary_num

    octal_num = ""
    for i in range(0, len(binary_num), 3):
        binary_group = binary_num[i:i+3]
        octal_digit = str(int(binary_group, 2))
        octal_num += octal_digit

    return f"The octal equivalent is: {octal_num}"

binary_tests = ["1101",  "101010",  "0000", "11111111", "1234" ]

for binary_test in binary_tests:
    print(f"Binary to Octal Test: {binary_test} -> {binary_to_octal(binary_test)}")



def octal_to_binary(octal_num):
    # Validate octal input
    for char in octal_num:
        if char not in '01234567':
            return "Invalid octal input. Please enter a valid octal number."
        
    binary_str = ""
    for digit in octal_num:
        binary_group = format(int(digit), '03b')
        binary_str += binary_group

    # Remove leading zeros, but keep at least one zero
    binary_num = binary_str.lstrip('0') or '0'

    return f"The binary equivalent is: {binary_num}"


octal_tests = ["10", "127","0", "777", "89"]

for octal_test in octal_tests:
    print(f"Octal to Binary Test: {octal_test} -> {octal_to_binary(octal_test)}")
# Out:
# 153 is an Armstrong number
# 370 is an Armstrong number
# 371 is an Armstrong number
# 9474 is an Armstrong number
# 9475 is not an Armstrong number
# Binary to Decimal Test: 1101 -> Decimal: 13
# Binary to Decimal Test: 101010 -> Decimal: 42
# Binary to Decimal Test: 0000 -> Decimal: 0
# Binary to Decimal Test: 11111111 -> Decimal: 255
# Binary to Decimal Test: 1234 -> Invalid binary input. Please enter a valid binary number.
# Decimal to Binary Test: 13 -> Binary: 1101
# Decimal to Binary Test: 42 -> Binary: 101010
# Decimal to Binary Test: 0 -> Binary: 0
# Decimal to Binary Test: 255 -> Binary: 11111111
# Decimal to Binary Test: -10 -> Invalid input. Please enter a positive integer.
# Octal to Decimal Test: 10 -> Decimal: 8
# Octal to Decimal Test: 127 -> Decimal: 87
# Octal to Decimal Test: 0 -> Decimal: 0
# Octal to Decimal Test: 777 -> Decimal: 511
# Octal to Decimal Test: 89 -> Invalid octal input. Please enter a valid octal number.
# Decimal to Octal Test: 13 -> Octal: 15
# ...
